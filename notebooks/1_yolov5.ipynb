# %%
# !pip install torch torchvision torchaudio
# !pip install opencv-python-headless
# !pip install roboflow
# !pip install deep-sort-realtime
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 84.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 77.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 57.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17270, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 17270 (delta 0), reused 0 (delta 0), pack-reused 17269 (from 2)
# Receiving objects: 100% (17270/17270), 16.12 MiB | 16.80 MiB/s, done.
# Resolving deltas: 100% (11858/11858), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 14.4 MB/s eta 0:00:00
# ...

# %%
# !python train.py --img 640 --batch 8 --epochs 50 --data /content/drive/MyDrive/Cheetah.v1i.yolov5pytorch/datasets.yaml --weights yolov5s.pt --device cpu
# Out:
# python3: can't open file '/content/train.py': [Errno 2] No such file or directory

# %%
# !pip install patool
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.3/86.3 kB 3.8 MB/s eta 0:00:00
# ...

# %%
import patoolib

# %%
patoolib.extract_archive('/content/Final_set.zip')
# Out:
# INFO patool: Extracting /content/Final_set.zip ...
# INFO:patool:Extracting /content/Final_set.zip ...
# INFO patool: running /usr/bin/7z x -aou -o./Unpack_cqafk42k -- /content/Final_set.zip
# INFO:patool:running /usr/bin/7z x -aou -o./Unpack_cqafk42k -- /content/Final_set.zip
# INFO patool: ... /content/Final_set.zip extracted to `Final_set' (multiple files in root).
# INFO:patool:... /content/Final_set.zip extracted to `Final_set' (multiple files in root).
# 'Final_set'

# %%
yaml_content = """
train: /content/Final_set/Final_set/train/images
val: /content/Final_set/Final_set/valid/images
test: /content/Final_set/Final_set/test/images

nc: 1  # Number of classes (change this if needed)
names: ['cheetah']  # Replace with your actual class names
"""

# Save the file
with open("/content/Final_set/Final_set/data1.yaml", "w") as f:
    f.write(yaml_content)

print("data1.yaml file created successfully!")
# Out:
# data1.yaml file created successfully!

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.8/993.8 kB 26.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 104.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 80.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 62.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5
# !cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17360, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 17360 (delta 36), reused 18 (delta 18), pack-reused 17308 (from 2)
# Receiving objects: 100% (17360/17360), 16.23 MiB | 28.13 MiB/s, done.
# Resolving deltas: 100% (11898/11898), done.
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !python /content/yolov5/train.py --resume --epochs 100 --weights /content/last.pt
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-04-06 10:02:21.904905: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743933742.204240    5020 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !python /content/yolov5/train.py --weights /content/last.pt --epochs 100 --data /content/Final_set/Final_set/data1.yaml --img 640 --batch 16 --name exp_continue
# Out:
# Streaming output truncated to the last 5000 lines.
#       63/99      4.47G    0.01817    0.01213          0         37        640:  59% 39/66 [00:13<00:10,  2.64it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       63/99      4.47G    0.01865    0.01212          0         38        640:  61% 40/66 [00:14<00:10,  2.55it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       63/99      4.47G    0.01877    0.01214          0         46        640:  62% 41/66 [00:14<00:08,  2.90it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
# !zip -r runs.zip /content/yolov5/runs
# Out:
#   adding: content/yolov5/runs/ (stored 0%)
#   adding: content/yolov5/runs/train/ (stored 0%)
#   adding: content/yolov5/runs/train/exp_continue/ (stored 0%)
#   adding: content/yolov5/runs/train/exp_continue/hyp.yaml (deflated 45%)
#   adding: content/yolov5/runs/train/exp_continue/opt.yaml (deflated 51%)
#   adding: content/yolov5/runs/train/exp_continue/train_batch0.jpg (deflated 1%)
#   adding: content/yolov5/runs/train/exp_continue/P_curve.png (deflated 19%)
#   adding: content/yolov5/runs/train/exp_continue/val_batch2_labels.jpg (deflated 6%)
#   adding: content/yolov5/runs/train/exp_continue/val_batch1_pred.jpg (deflated 4%)
#   adding: content/yolov5/runs/train/exp_continue/train_batch2.jpg (deflated 1%)
#   adding: content/yolov5/runs/train/exp_continue/val_batch0_pred.jpg (deflated 5%)
#   adding: content/yolov5/runs/train/exp_continue/weights/ (stored 0%)
#   adding: content/yolov5/runs/train/exp_continue/weights/best.pt (deflated 9%)
# ...

# %%
from google.colab import files
files.download("runs.zip")

# %%
# !python /content/yolov5/val.py --weights /content/yolov5/runs/train/exp_continue/weights/best.pt --data /content/Final_set/Final_set/data1.yaml --task test --img 640
# Out:
# val: data=/content/Final_set/Final_set/data1.yaml, weights=['/content/yolov5/runs/train/exp_continue/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=yolov5/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-411-gf4d8a84c Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning /content/Final_set/Final_set/test/labels... 150 images, 0 backgrounds, 0 corrupt: 100% 150/150 [00:00<00:00, 341.26it/s]
# test: New cache created: /content/Final_set/Final_set/test/labels.cache
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:04<00:00,  1.17it/s]
# ...

# %%
# !zip -r cheetah_project.zip yolov5 yolov5_200.ipynb
# Out:
# 	zip warning: name not matched: yolov5
# 	zip warning: name not matched: yolov5_200.ipynb
#
# zip error: Nothing to do! (try: zip -r cheetah_project.zip . -i yolov5 yolov5_200.ipynb)
